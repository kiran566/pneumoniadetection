# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/"
# Out:
#  38WT-27-12
# '38WT-27 12.gdoc'
# '6.a)APPLICATIONS OF DERIVATIVES.pdf'
# 'AI Chatbot SVG Icon.gdoc'
#  Anaysis_customerChurn.gdoc
# 'Boston Housing Dataset Analysis.gdoc'
#  clf.pkl
# 'COA LAB-03.gdoc'
# 'COA -LAB2.gdoc'
# 'Colab Notebooks'
# 'Copy of 1.a)TRIGONOMETRIC RELATIONS.pdf'
# 'Copy of AIM:To verify half adder,full adder,full adder using half adders,half                  subtractor,fullsubtractor,full subtractor using half subtractors.gdoc'
#  darkweb.gdoc
#  ECG_SRS.gdoc
#  Jhgh
# 'JUST ADD IT INTO A TABLE.gsheet'
#  LAB05.gdoc
#  LAB-06.gdoc
#  LAB1031.gdoc
#  N210714_C0A-1.pdf
#  pneumoniadetection.zip
# 'Project Name : FLEET QUEST.gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document.gdoc'

# %%
# !cp "/content/drive/MyDrive/pneumoniadetection.zip" ./

# %%
# !ls
# Out:
# drive  pneumoniadetection.zip  sample_data

# %%
# !unzip -q pneumoniadetection.zip -d ./

# %%
# !ls /content/pneumoniadetection
# Out:
# dataset  LICENSE  README.md  requirements.txt  src  venv

# %%
# %cd /content/pneumoniadetection/src
# Out:
# /content/pneumoniadetection/src

# %%
# !ls
# Out:
# data_loader.py	model.py  model_sum.py	__pycache__  train.py

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 114.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 104.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.1 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !python train.py
# Out:
# 2025-12-03 06:54:24.394646: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764744864.416966    1893 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764744864.423332    1893 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764744864.438767    1893 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from google.colab import files
files.download('/content/pneumoniadetection/src/best_model.h5')
